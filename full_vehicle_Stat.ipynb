# %%
import pandas as pd
df1 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Bio-Diesel_PassengerVehicle_Stats.csv")
df1
df2 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Compressed Natural Gas_PassengerVehicle_Stats.csv")
df2
df3 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Diesel_PassengerVehicle_Stats.csv")
df3
df4 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Electric_PassengerVehicle_Stats.csv")
df4
df5 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Flex Fuel_PassengerVehicle_Stats.csv")
df5
df6 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Gasoline_PassengerVehicle_Stats.csv")
df6
df7 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Horse_PassengerVehicle_Stats.csv")
df7
df8 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Hybrid_PassengerVehicle_Stats.csv")
df8
df9 = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\Python g project\CASE3\PassengerVehicle_Stats\Pedal_PassengerVehicle_Stats.csv")
df9
# Out:
#      Unnamed: 0  Public Vehicle Number     Status Vehicle Make Vehicle Model  \
# 0            61                     77  VIOLATION   MAINSTREET       CLASSIC
# 1           103                    131     ACTIVE      MANMADE         WAGON
# 2           168                    186     ACTIVE      MANMADE      BROADWAY
# 3           227                     69  VIOLATION   MAINSTREET       CLASSIC
# 4           261                    142     ACTIVE          VIP           VIP
# ..          ...                    ...        ...          ...           ...
# 210       16143                     42     ACTIVE    PRECISION      6 SEATER
# 211       16151                     52     ACTIVE      SCHWINN          NONE
# 212       16216                     70  VIOLATION   MAINSTREET       CLASSIC
# 213       16229                     57  VIOLATION   MAINSTREET     BOARDWALK
# 214       16281                    117     ACTIVE      SCHWINN          NONE
#
# ...

# %%
vehicles_df = pd.concat([df1, df2, df3, df4, df6,df7, df8, df9], join = 'inner' )
vehicles_df
# Out:
#      Unnamed: 0  Public Vehicle Number     Status Vehicle Make Vehicle Model  \
# 0          1286                  12009   RESERVED    CHEVROLET       EXPRESS
# 1          2095                  12248   INACTIVE     MERCEDES      SPRINTER
# 2          7950                  13527   INACTIVE     VAN HOOL         TD925
# 3          8700                  12248   INACTIVE     MERCEDES      SPRINTER
# 4          9359                  13528   INACTIVE     VAN HOOL         TD925
# ..          ...                    ...        ...          ...           ...
# 210       16143                     42     ACTIVE    PRECISION      6 SEATER
# 211       16151                     52     ACTIVE      SCHWINN          NONE
# 212       16216                     70  VIOLATION   MAINSTREET       CLASSIC
# 213       16229                     57  VIOLATION   MAINSTREET     BOARDWALK
# 214       16281                    117     ACTIVE      SCHWINN          NONE
#
# ...

# %%
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16410 entries, 0 to 214
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          16410 non-null  int64
#  1   Public Vehicle Number               16410 non-null  int64
#  2   Status                              16410 non-null  object
#  3   Vehicle Make                        14493 non-null  object
#  4   Vehicle Model                       14447 non-null  object
#  5   Vehicle Model Year                  14468 non-null  float64
#  6   Vehicle Color                       14424 non-null  object
#  7   Vehicle Fuel Source                 16410 non-null  object
#  8   Wheelchair Accessible               16410 non-null  object
#  9   Company Name                        16410 non-null  object
#  10  Address                             14624 non-null  object
# ...

# %%
vehicles_df.describe()
# Out:
#          Unnamed: 0  Public Vehicle Number  Vehicle Model Year      ZIP Code
# count  16410.000000           1.641000e+04        14468.000000  14624.000000
# mean    8305.539549           3.894966e+04         2012.650608  60612.230990
# std     4793.488758           1.380441e+05           84.175090    104.864048
# min        0.000000           0.000000e+00            0.000000  60004.000000
# 25%     4155.250000           3.674250e+03         2013.000000  60619.000000
# 50%     8308.500000           7.064500e+03         2016.000000  60631.000000
# 75%    12457.750000           1.737700e+04         2021.000000  60645.000000
# max    16601.000000           6.902206e+06         2025.000000  61111.000000

# %%
vehicles_df.dtypes
# Out:
# Unnamed: 0                              int64
# Public Vehicle Number                   int64
# Status                                 object
# Vehicle Make                           object
# Vehicle Model                          object
# Vehicle Model Year                    float64
# Vehicle Color                          object
# Vehicle Fuel Source                    object
# Wheelchair Accessible                  object
# Company Name                           object
# Address                                object
# City                                   object
# State                                  object
# ZIP Code                              float64
# Taxi Affiliation                       object
# Taxi Medallion License Management      object
# Record ID                              object
# dtype: object

# %%
#drop duplicated

# %%
vehicles_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 210    False
# 211    False
# 212    False
# 213    False
# 214    False
# Length: 16410, dtype: bool

# %% [markdown]
# #no duplicated values in this list

# %%
vehicles_df.columns
# Out:
# Index(['Unnamed: 0', 'Public Vehicle Number', 'Status', 'Vehicle Make',
#        'Vehicle Model', 'Vehicle Model Year', 'Vehicle Color',
#        'Vehicle Fuel Source', 'Wheelchair Accessible', 'Company Name',
#        'Address', 'City', 'State', 'ZIP Code', 'Taxi Affiliation',
#        'Taxi Medallion License Management ', 'Record ID'],
#       dtype='object')

# %%
vehicles_df= vehicles_df[[ 'Public Vehicle Number', 'Status', 'Vehicle Make',
       'Vehicle Model', 'Vehicle Model Year', 'Vehicle Color',
       'Vehicle Fuel Source', 'Wheelchair Accessible', 'Company Name',
         'Record ID']]
vehicles_df
# Out:
#      Public Vehicle Number     Status Vehicle Make Vehicle Model  \
# 0                    12009   RESERVED    CHEVROLET       EXPRESS
# 1                    12248   INACTIVE     MERCEDES      SPRINTER
# 2                    13527   INACTIVE     VAN HOOL         TD925
# 3                    12248   INACTIVE     MERCEDES      SPRINTER
# 4                    13528   INACTIVE     VAN HOOL         TD925
# ..                     ...        ...          ...           ...
# 209                     29     ACTIVE    PRECISION      6 SEATER
# 210                     42     ACTIVE    PRECISION      6 SEATER
# 211                     52     ACTIVE      SCHWINN          NONE
# 213                     57  VIOLATION   MAINSTREET     BOARDWALK
# 214                    117     ACTIVE      SCHWINN          NONE
#
#      Vehicle Model Year Vehicle Color Vehicle Fuel Source  \
# 0                2014.0         BLACK          Bio-Diesel
# 1                2010.0        SILVER          Bio-Diesel
# ...

# %% [markdown]
# #Address, City, State, ZIP Code, Taxi Affiliation,Taxi Medallion License Management  not more importent for our analysis. Because we are forcuse  analyzing data on registered public passenger vehicles in Illinois and get desission.

# %%
missing_values = vehicles_df.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0                               0
# Public Vehicle Number                    0
# Status                                   0
# Vehicle Make                          1917
# Vehicle Model                         1963
# Vehicle Model Year                    1942
# Vehicle Color                         1986
# Vehicle Fuel Source                      0
# Wheelchair Accessible                    0
# Company Name                             0
# Address                               1786
# City                                  1786
# State                                 1786
# ZIP Code                              1786
# Taxi Affiliation                      9245
# Taxi Medallion License Management     9272
# Record ID                                0
# dtype: int64

# %%
Q1 = vehicles_df['Vehicle Model Year'].quantile(0.25)
Q3 = vehicles_df['Vehicle Model Year'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR


vehicles_df = vehicles_df[(vehicles_df['Vehicle Model Year'] >= lower_bound) & (vehicles_df['Vehicle Model Year'] <= upper_bound)]

# %%
missing_values = vehicles_df.isnull().sum()
print(missing_values)
# Out:
# Public Vehicle Number     0
# Status                    0
# Vehicle Make              9
# Vehicle Model            54
# Vehicle Model Year        0
# Vehicle Color             0
# Vehicle Fuel Source       0
# Wheelchair Accessible     0
# Company Name              0
# Record ID                 0
# dtype: int64

# %%
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14276 entries, 0 to 214
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Public Vehicle Number  14276 non-null  int64
#  1   Status                 14276 non-null  object
#  2   Vehicle Make           14267 non-null  object
#  3   Vehicle Model          14222 non-null  object
#  4   Vehicle Model Year     14276 non-null  float64
#  5   Vehicle Color          14276 non-null  object
#  6   Vehicle Fuel Source    14276 non-null  object
#  7   Wheelchair Accessible  14276 non-null  object
#  8   Company Name           14276 non-null  object
#  9   Record ID              14276 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.2+ MB
